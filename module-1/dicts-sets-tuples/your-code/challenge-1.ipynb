# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
# Your code here
tup=(1,)
print (tup)
# Out:
# (1,)

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
# Your code here 
print(type(tup))

#amazing!, it is a tuple!
# Out:
# <class 'tuple'>

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
# Your code here
#I first convert my tuple to a list
ltup=list(tup)
print (ltup)
# then I append whatever elements I like
    #I create the list
elements=["r", "o", "n", "h", "a", "c", "k"]
    # I iterate and append
for i in elements:
    ltup.append(i)
print (ltup)
    # and I convert my list into a tuple again
tup1=tuple(ltup)
print (tup1)
print(elements)          
# and then I convert the resulting list to a tuple again, so I get a tuple that has my original element + the appended ones
print (tup1)

# Your explanation here
#tuples, like Charlton Heston face, are inmutables, so the only way to make the fiction of an append to a taple must be to change it into a list and change it back into a tuple
# Out:
# [1]
# [1, 'r', 'o', 'n', 'h', 'a', 'c', 'k']
# (1, 'r', 'o', 'n', 'h', 'a', 'c', 'k')
# ['r', 'o', 'n', 'h', 'a', 'c', 'k']
# (1, 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
# Your code here
#I  convert it again my tuple to a list
ltup=list(tup)

#then I clear the list so it becomes an empty list
ltup.clear()
print (ltup)

# then I append whatever elements I like
    #I create the list
elements=["I", "r", "o", "n", "h", "a", "c", "k"]
    # and now I realise that the elements of the tuple compound the word Ironhack, given the long weeks of confination, I would rather cghange it to  "I", "rum" hack"
    # I iterate and append
for i in elements:
    ltup.append(i)
print (ltup)
    # and I convert my list into a tuple again
tup1=tuple(ltup)
print (tup1)
print(elements)          
# and then I convert the resulting list to a tuple again, so I get a tuple that has my original element + the appended ones
print (tup1)



# Your explanation here
# Out:
# []
# ['I', 'r', 'o', 'n', 'h', 'a', 'c', 'k']
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')
# ['I', 'r', 'o', 'n', 'h', 'a', 'c', 'k']
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
# Your code here
a=len (tup1)
n=int(a/2)
listupa=[]
listupb=[]
for i in range (n):
    tupa=tup1[7-i]
    tupb=tup1[i]
    listupa.append(tupa)
    listupb.append(tupb)
print (listupa)
print (listupb)

  # and I convert my list into a tuple again
listupa_r = list(reversed(listupa)) #for the sake of beauty, I order the list before converting it back to a tuple
tupa=tuple(listupa_r)
tupb = tuple (listupb)

print (tupa)
print (tupb)
# Out:
# ['k', 'c', 'a', 'h']
# [1, 'r', 'o', 'n']
# ('h', 'a', 'c', 'k')
# (1, 'r', 'o', 'n')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
# Your code here
tupall=tupb+tupa
print (tup)
print (tupall)
# Out:
# (1,)
# (1, 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`.

# %%
# Your code here
z=len(tupa)
q=len(tupb)
y=len(tupall)
print (z)
print (y)
print (q)
# Out:
# 4
# 8
# 4

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
# Your code here
d=len(tupall)
for i in range (d):
    if tupall[i]=="h":
        a=1
print (a)
# Out:
# 1

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
# Your code here
letters = ["a", "b", "c", "d", "e"]
coincidences=[(i) for i in letters for j in tupall if i==j] # First the elegant and quick
print (coincidences)

for j in tupall: #second "by the books"
    if j in letters:
        print (f"{j} True")
    else:
        print (f"{j} False")
# Out:
# ['a', 'c']
# 1 False
# r False
# o False
# n False
# h False
# a True
# c True
# k False

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
# Your code here
for j in tupall: #second "by the books"
    if j in letters:
        cl=tupall.count(j)
        print (f"{j} appears {cl} times in {letters}")
    else:
        print (f"{j} does not appear in {letters}")
# Out:
# 1 does not appear in ['a', 'b', 'c', 'd', 'e']
# r does not appear in ['a', 'b', 'c', 'd', 'e']
# o does not appear in ['a', 'b', 'c', 'd', 'e']
# n does not appear in ['a', 'b', 'c', 'd', 'e']
# h does not appear in ['a', 'b', 'c', 'd', 'e']
# a appears 1 times in ['a', 'b', 'c', 'd', 'e']
# c appears 1 times in ['a', 'b', 'c', 'd', 'e']
# k does not appear in ['a', 'b', 'c', 'd', 'e']
