# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
# Your code here
tup = ('I',)

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
# Your code here
type(tup)
# Out:
# tuple

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
# Your code here
tup = tup.append('r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a6f9c712cf9b> in <module>
#       1 # Your code here
# ----> 2 tup = tup.append('r')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tup = list(tup)
print(type(tup) )

tup += ['r', 'o', 'n', 'h', 'a', 'c', 'k']
    
print(tup, type(tup))

tup = tuple(tup)
print(tup, type(tup))

# Since theyre unmutable objects, no elements can be added. However, we can transform them into list, operate with them and go back to a tuple object.

print()

# Other option it's adding two tuples:

tup = ('I',)
tup2 = ('r', 'o', 'n', 'h', 'a', 'c', 'k')

tup += tup2

print(tup, type(tup))
# Out:
# <class 'list'>
# ['I', 'r', 'o', 'n', 'h', 'a', 'c', 'k'] <class 'list'>
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k') <class 'tuple'>
#
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k') <class 'tuple'>

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
# Your code here
tup[-1] = 'X'

# Your explanation here
# We can read a position inside a tuple using it's index but we can't change its value meanwhile it's a tuple.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-da45c03a34d1> in <module>
#       1 # Your code here
# ----> 2 tup[-1] = 'X'
#       3
#       4 # Your explanation here
#       5 # We can read a position inside a tuple using it's index but we can't change its value meanwhile it's a tuple.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
# Your code here
tup =("I", "r", "o", "n", "h", "a", "c", "k")

tup1 = tuple([i for i in list(tup)[:4]])
tup2 = tuple([i for i in list(tup)[-4:]])
print(tup1)
print(tup2)
# Out:
# ('I', 'r', 'o', 'n')
# ('h', 'a', 'c', 'k')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
# Your code here
tup3 = tup1 + tup2
print(tup3)
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`.

# %%
# Your code here
True if len(tup1)+len(tup2) == len(tup) else False
# Out:
# True

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
# Your code here
print(tup3.index('h'))
# Out:
# 4

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
# Your code here
letters = ["a", "b", "c", "d", "e"]

print(f'The letter {l} is in tup3: ', True) for l in letter if l in tup3 else print(f'The letter {l} is in tup3: ', False)
# Out:
#   File "<ipython-input-9-9006e9822d2d>", line 4
#     print(f'The letter {l} is in tup3: ', True) for l in letter if l in tup3 else print(f'The letter {l} is in tup3: ', False)
#                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
# Your code here
for l in letters:
    print(f'The letter {l} appears ',tup3.count(l),'times.' )
# Out:
# The letter a appears  1 times.
# The letter b appears  0 times.
# The letter c appears  1 times.
# The letter d appears  0 times.
# The letter e appears  0 times.
