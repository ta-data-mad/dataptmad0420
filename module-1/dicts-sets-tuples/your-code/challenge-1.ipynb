# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
# Your code here
tup = ('I',)

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
# Your code here
type(tup)
# Out:
# tuple

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
# Your code here
n_tup = ("r", "o", "n", "h", "a", "c", 'k')

ytup = tup + n_tup
print(ytup)
# here I was doing the next challenge before reading it thats why I tried to add them up here too.
#But I have a question here because everytime i ran the code it was adding another n_tup to the ones printed before, why is it ?
""""
# Your explanation here
#You can't really append anaything really to the tuple because tuples are not mutable, and in this case because we would
get a syntax error caused by the mispelling in the "k' character. We would have to make another tuple and add them up.
""""
# Out:
#   File "<ipython-input-5-6bb9587b3a9c>", line 12
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
n_tup = ("r", "o", "n", "h", "a", "c", 'k')
tup = ('I',)

y_tup = tup + n_tup
print(y_tup)

# Your code here

# Your explanation here
#Here we are not manipulating the tuples we are just merging them, so thats why we dont raise an error.
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
tup = ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

tup1 = tup[:4]
tup2 = tup[-4:]
# Your code here
print(tup1)
print()
print(tup2)
# Out:
# ('I', 'r', 'o', 'n')
#
# ('h', 'a', 'c', 'k')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
# Your code here
tup3 = tup1 + tup2
print(tup3)
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`.

# %%
# Your code here
print(len(tup1),len(tup2))

if tup1 + tup2 == tup3:
    print('They are equal.')
#I tried to do it in a list comprenhension way but I didnt know how to approach it
# Out:
# 4 4
# They are equal.

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
# Your code here
tup.index('h')
# Out:
# 4

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
# Your code here
letters = ["a", "b", "c", "d", "e"]

for l in letters:
    if l in tup3:
        print(True)
    else:
        print(False)
# Out:
# True
# False
# True
# False
# False

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
# Your code here
letters = ["a", "b", "c", "d", "e"]
cnt = []

for l in letters:
    if l in tup3:
        cnt.append(l)
        print(cnt)
        print(cnt.count(l))
        
    
#Here I got the number os appearances of eahc letter but couldn't manage to display it like a dictionary, or sow the letter at the smae time
# Out:
# ['a']
# 1
# ['a', 'c']
# 1
