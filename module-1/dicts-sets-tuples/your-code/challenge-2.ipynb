# %% [markdown]
# ## Challenge 2: Sets
#
# There are a lot to learn about Python Sets and the information presented in the lesson is limited due to its length. To learn Python Sets in depth you are strongly encouraged to review the W3Schools tutorial on [Python Sets Examples and Methods](https://www.w3schools.com/python/python_sets.asp) before you work on this lab. Some difficult questions in this lab have their solutions in the W3Schools tutorial.
#
# #### First, import the Python `random` library.

# %%
import random

# %% [markdown]
# #### In the cell below, create a list named `sample_list_1` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * Each value in the list is unique.
#
# Print `sample_list_1` to review its values
#
# *Hint: use `random.sample` ([reference](https://docs.python.org/3/library/random.html#random.sample)).*

# %%
# Your code here

sample_list_1 = set(random.sample(range(100),80))

print(sample_list_1)
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 10, 12, 13, 15, 16, 17, 18, 19, 20, 22, 23, 24, 25, 26, 27, 28, 29, 30, 32, 33, 35, 36, 37, 38, 39, 40, 42, 43, 45, 46, 47, 48, 49, 50, 51, 52, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 83, 84, 86, 88, 89, 90, 92, 93, 94, 95, 96, 97, 98, 99}

# %% [markdown]
# #### Convert `sample_list_1` to a set called `set1`. Print the length of the set. Is its length still 80?

# %%
# Your code here

set1 = set(sample_list_1)

print(len(set1))
# Out:
# 80

# %% [markdown]
# #### Create another list named `sample_list_2` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * The values in the list don't have to be unique.
#
# *Hint: Use a FOR loop.*

# %%
# Your code here

sample_list_2 = set([random.randint(0,100) for i in range(80)])

print(sample_list_2)
# Out:
# {0, 4, 6, 8, 12, 14, 16, 17, 18, 21, 22, 23, 24, 25, 28, 30, 32, 34, 35, 37, 38, 39, 40, 41, 43, 45, 47, 52, 53, 54, 55, 57, 58, 59, 60, 62, 63, 67, 68, 70, 72, 74, 78, 80, 82, 84, 85, 86, 88, 91, 92, 96, 98, 99, 100}

# %% [markdown]
# #### Convert `sample_list_2` to a set called `set2`. Print the length of the set. Is its length still 80?

# %%
# Your code here

set2 = set(sample_list_2)

print(len(set2))
# Out:
# 55

# %% [markdown]
# #### Identify the elements present in `set1` but not in `set2`. Assign the elements to a new set named `set3`.

# %%
# Your code here

set3 = set([i for i in set1 if i not in set2])

print(set3)
# Out:
# {1, 3, 5, 7, 9, 10, 13, 15, 19, 20, 26, 27, 29, 33, 36, 42, 46, 48, 49, 50, 51, 61, 64, 65, 66, 71, 73, 75, 76, 77, 79, 81, 83, 89, 90, 93, 94, 95, 97}

# %% [markdown]
# #### Identify the elements present in `set2` but not in `set1`. Assign the elements to a new set named `set4`.

# %%
# Your code here

set4 = set([i for i in set2 if i not in set1])

print(set4)
# Out:
# {0, 34, 100, 70, 41, 14, 82, 21, 53, 54, 55, 57, 85, 91}

# %% [markdown]
# #### Now Identify the elements shared between `set1` and `set2`. Assign the elements to a new set named `set5`.

# %%
# Your code here

set5 = set([i for i in set1 if i in set2])

print(set5)
# Out:
# {4, 6, 8, 12, 16, 17, 18, 22, 23, 24, 25, 28, 30, 32, 35, 37, 38, 39, 40, 43, 45, 47, 52, 58, 59, 60, 62, 63, 67, 68, 72, 74, 78, 80, 84, 86, 88, 92, 96, 98, 99}

# %% [markdown]
# #### What is the relationship among the following values:
#
# * len(set1)
# * len(set2)
# * len(set3)
# * len(set4)
# * len(set5)
#
# Use a math formular to represent that relationship. Test your formular with Python code.

# %%
# Your code here

print(len(set1))
print(len(set2))
print(len(set3))
print(len(set4))
print(len(set5))

print(len(set1) + len(set2) == len(set3) + len(set4) + (2*(len(set5))))
# Out:
# 80
# 55
# 39
# 14
# 41
# True

# %% [markdown]
# #### Create an empty set called `set6`.

# %%
# Your code here

set6 = set()

# %% [markdown]
# #### Add `set3` and `set5` to `set6` using the Python Set `update` method.

# %%
# Your code here

set6.update (set3,set5)

print(set6)
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 10, 12, 13, 15, 16, 17, 18, 19, 20, 22, 23, 24, 25, 26, 27, 28, 29, 30, 32, 33, 35, 36, 37, 38, 39, 40, 42, 43, 45, 46, 47, 48, 49, 50, 51, 52, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 83, 84, 86, 88, 89, 90, 92, 93, 94, 95, 96, 97, 98, 99}

# %% [markdown]
# #### Check if `set1` and `set6` are equal.

# %%
# Your code here

print(set1 == set6)
# Out:
# True

# %% [markdown]
# #### Check if `set1` contains `set2` using the Python Set `issubset` method. Then check if `set1` contains `set3`.*

# %%
# Your code here

print(set2.issubset(set1))

print(set3.issubset(set1))
# Out:
# False
# True

# %% [markdown]
# #### Using the Python Set `union` method, aggregate `set3`, `set4`, and `set5`. Then aggregate `set1` and `set2`.
#
# #### Check if the aggregated values are equal.

# %%
# Your code here

set345 = (set3.union(set4)).union(set5)
set12 = set1.union(set2)

print(set345 == set12)
# Out:
# True

# %% [markdown]
# #### Using the `pop` method, remove the first element from `set1`.

# %%
# Your code here

set1 = list(set1)

set1.pop(0)

print(set1)
# Out:
# [3, 4, 5, 6, 7, 8, 9, 10, 12, 13, 15, 16, 17, 18, 19, 20, 22, 23, 24, 25, 26, 27, 28, 29, 30, 32, 33, 35, 36, 37, 38, 39, 40, 42, 43, 45, 46, 47, 48, 49, 50, 51, 52, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 83, 84, 86, 88, 89, 90, 92, 93, 94, 95, 96, 97, 98, 99]

# %% [markdown]
# #### Remove every element in the following list from `set1` if they are present in the set. Print the remaining elements.
#
# ```
# list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
# ```

# %%
# Your code here

list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]

for i in set1:
    if i in list_to_remove:
        set1.pop(set1.index(i))
        
print(set1)
# Out:
# [3, 4, 5, 6, 7, 8, 10, 12, 13, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28, 30, 32, 33, 35, 36, 37, 38, 40, 42, 43, 45, 46, 47, 48, 50, 52, 58, 60, 62, 63, 64, 65, 66, 67, 68, 72, 73, 74, 75, 76, 77, 78, 80, 83, 84, 86, 88, 90, 92, 93, 94, 95, 96, 97, 98]
