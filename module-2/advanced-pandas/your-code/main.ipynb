# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
df = pd.read_csv('../data/Admission_Predict.csv')

df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.72
# 2           1              0.80
# 3           0              0.65
# 4           1              0.90
# ..        ...               ...
# 380         1              0.82
# 381         1              0.84
# 382         1              0.91
# 383         0              0.67
# 384         1              0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here

# No spaces

df = df.rename(columns={'LOR ': 'LOR'})

list(df.columns)[5]
# Out:
# 'LOR'

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here

df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
count=0
for i in range(len(df.columns)):
    for j in range(len(df.index)):
        if df.isnull().iloc[j, i] == 'True':
            print((j,i))
        else:
            count = count + 1
            
print(count) # Counting of evaluation
print(len(df.index)*len(df.columns)) # Total number of elements

# There is no missing data
# Out:
# 3465
# 3465

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html
# your code here
new_df = df.set_index('Serial No.')

new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.72
# 3                  1              0.80
# 4                  0              0.65
# 5                  1              0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here

df.set_index(['GRE Score', 'CGPA'],inplace=True)

df.head() # NO need to assign new variable, because (inplace=True)

# new_df_2 = df.set_index(['GRE Score', 'CGPA'],inplace=True), Pq?
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 337       9.65           1          118                  4  4.5  4.5
# 316       8.00           2          104                  3  3.0  3.5
# 322       8.67           3          110                  3  3.5  2.5
# 314       8.21           4          103                  2  2.0  3.0
# 330       9.34           5          115                  5  4.5  3.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1              0.92
# 316       8.00         1              0.72
# 322       8.67         1              0.80
# 314       8.21         0              0.65
# 330       9.34         1              0.90

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html
# your code here

df.reset_index(inplace=True)

df.head()

#df_2 = new_df_2.reset_index(inplace=True), Pq?

# Understanding inplace=True
#https://stackoverflow.com/questions/43893457/understanding-inplace-true
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        337  9.65           1          118                  4  4.5  4.5
# 1        316  8.00           2          104                  3  3.0  3.5
# 2        322  8.67           3          110                  3  3.5  2.5
# 3        314  8.21           4          103                  2  2.0  3.0
# 4        330  9.34           5          115                  5  4.5  3.0
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here

#Listing the data

CGPA_up9 = [df.iloc[i, 2] for i in range(len(df['CGPA'])) if df.iloc[i, 1] > 9]
do_research = [df.iloc[int(i-1), 2] for i in CGPA_up9 if df.iloc[int(i-1), 7] == 1]

lst_lst = [[df.iloc[int(i-1), j] for j in range(9)] for i in do_research]
colnames = list(df.columns)

# number of rows where the CGPA is higher than 9 and the student has conducted research.
amount_studets_1 = len(do_research) 


# New DataFrame
highCGPA_research = pd.DataFrame(lst_lst, columns=colnames)

# Print
print(amount_studets_1)

highCGPA_research.head()
# Out:
# 101
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        337  9.65           1          118                  4  4.5  4.5
# 1        330  9.34           5          115                  5  4.5  3.0
# 2        328  9.10          11          112                  4  4.0  4.5
# 3        328  9.50          20          116                  5  5.0  5.0
# 4        334  9.70          21          119                  5  5.0  4.5
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.90
# 2         1              0.78
# 3         1              0.94
# 4         1              0.95

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here

#Listing the data
sop_down3half = [df.iloc[int(i-1), 2] for i in CGPA_up9 if df.iloc[int(i-1), 5] < 3.5]
lst_lst_2 = [[df.iloc[int(i-1), j] for j in range(9)] for i in sop_down3half]

# number of rows where the CGPA is higher than 9 and the SOP score is less than 3.5.
amount_studets_2 = len(sop_down3half) 

# New DataFrame
highCGPA_lowSOP = pd.DataFrame(lst_lst_2, columns=colnames)

# Print
print(amount_studets_2)

highCGPA_lowSOP
# Out:
# 5
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        338  9.40          29          118                  4  3.0  4.5
# 1        327  9.02          63          114                  3  3.0  3.0
# 2        326  9.11         141          114                  3  3.0  3.0
# 3        324  9.01         218          111                  4  3.0  3.0
# 4        325  9.11         382          107                  3  3.0  3.5
#
#    Research  Chance of Admit
# 0         1              0.91
# 1         0              0.61
# 2         1              0.83
# 3         1              0.82
# 4         1              0.84

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    # your code here
    # mean and standard deviation calculation
    std = np.std(col)
    mean = np.mean(col)
    # New column
    new_col = (col-mean)/std
    return new_col

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here

df['CGPA_std'] = standardize(df['CGPA'])
df['GRE_std'] = standardize(df['GRE Score'])
df['LOR_std'] = standardize(df['LOR'])  

df.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        337  9.65           1          118                  4  4.5  4.5
# 1        316  8.00           2          104                  3  3.0  3.5
# 2        322  8.67           3          110                  3  3.5  2.5
# 3        314  8.21           4          103                  2  2.0  3.0
# 4        330  9.34           5          115                  5  4.5  3.0
#
#    Research  Chance of Admit   CGPA_std   GRE_std   LOR_std
# 0         1              0.92  1.750174  1.755663  1.193197
# 1         1              0.72 -0.992501 -0.063450  0.076840
# 2         1              0.80  0.121191  0.456297 -1.039517
# 3         0              0.65 -0.643433 -0.236698 -0.481338
# 4         1              0.90  1.234884  1.149292 -0.481338

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=df.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here

#df['deciding_column'] = df.lookup(df.index, df['best'])

#df.lookup(df.index, df['best'])

df.lookup(df.index,decision_choice)
# Out:
# array([ 1.1931973 ,  0.07684017, -1.03951697, -0.23669832,  1.23488366,
#        -0.66005529,  0.63501873, -1.27619097,  0.54292116,  0.66972643,
#         0.97604309, -0.4813384 , -1.59769554, -1.03951697, -0.4813384 ,
#        -0.99250072,  0.337281  , -0.4813384 ,  0.71616993,  1.50084   ,
#         1.1931973 ,  1.66903819,  0.337281  , -1.62268852, -2.32228243,
#        -0.58319587, -0.826278  ,  0.63501873,  1.84228696,  0.63501873,
#         1.75137587,  1.00217186, -1.53606413, -1.59769554, -1.10294219,
#        -1.49116886, -0.75644465, -1.03951697, -0.16138714,  0.63501873,
#         0.80279432,  0.45629677,  1.16839457,  0.63501873,  1.75137587,
#        -0.32760986, -0.49383257, -0.4099471 , -0.4813384 , -0.826278  ,
#         0.07684017,  0.283048  , -1.98983701, -1.59769554, -1.59769554,
#        -0.49383257, -0.826278  , -0.84306903, -1.10294219, -0.15007394,
#         0.17105828,  0.53674826, -0.4813384 ,  0.07684017,  1.0354164 ,
#         0.93568277,  1.75137587,  1.93301906,  1.41772864,  0.73621551,
#         0.50350371,  1.06266748,  0.88941871, -0.62681075, -1.59769554,
#        -2.05632609, -0.4813384 ,  1.75137587,  0.283048  ,  1.2681282 ,
#         2.01553574,  0.1045692 ,  0.07684017,  0.02317484,  0.07684017,
#        -1.12547889,  0.07684017, -0.4813384 , -1.36281536, -1.03951697,
#        -1.25845706, -0.4813384 ,  0.63501873,  1.06866094,  0.54292116,
#         0.07684017, -0.4099471 , -0.57694393, -0.21125396,  0.80279432,
#         0.30403646,  0.96892731,  1.84228696,  1.75137587, -1.10294219,
#        -0.4813384 ,  0.36967238, -1.36281536,  0.07684017, -0.49657149,
#         1.1931973 ,  0.03808011, -1.03951697,  0.07684017,  0.88941871,
#         1.75137587,  1.46759546, -0.39409895, -0.75644465, -0.4813384 ,
#        -0.4813384 , -0.4813384 ,  0.18768056, -0.4813384 ,  1.75137587,
#         1.93301906, -1.18956658,  0.30403646,  1.40916503,  0.63501873,
#        -0.72654437,  0.8027046 ,  0.86919369,  1.06266748,  1.2681282 ,
#         0.07684017,  0.63501873,  0.71616993,  0.07132466, -0.15007394,
#        -0.4813384 ,  1.99950815, -0.56032166,  1.49578941,  1.32254064,
#         0.36967238,  0.62954554,  0.07684017, -0.4813384 , -0.42734349,
#        -1.03951697, -0.92969342, -1.59769554, -1.22521252, -1.62268852,
#        -0.16138714, -0.06165352,  0.6863487 ,  0.61985961, -0.44396576,
#        -0.4813384 , -1.32494615, -0.49657149, -0.4099471 ,  0.78608233,
#         0.88581596,  1.05203867,  0.36967238,  0.283048  ,  1.06266748,
#         0.07684017, -0.79303346, -0.84306903, -1.44943974, -1.03951697,
#        -1.19196798, -0.23669832,  0.88941871,  0.13781374,  1.40110637,
